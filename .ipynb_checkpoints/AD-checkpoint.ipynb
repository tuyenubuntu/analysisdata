# %%
import os
import pandas as pd
import openpyxl
from openpyxl import load_workbook, Workbook

path = 'TWI 2023 1.xlsx'
df = pd.read_excel(path, sheet_name = 3)

df['Change Representative/ Tác giả']
# Out:
# 0         Le Minh Nhat (HcP/MFE3.11)
# 1          Trinh Phu Hien (HcP/MFE3)
# 2       Nguyen Van Hoa (HcP/MFE3.11)
# 3         Vo Minh Thanh (HcP/MFE3.2)
# 4      Lam Thai Nhat Toan (HcP/MFI3)
#                    ...
# 393    Van Tran Dang Khoa (HcP/MFI3)
# 394          Vo Thien Tam (HcP/MFE3)
# 395    Van Tran Dang Khoa (HcP/MFI3)
# 396         Nguyen Van Ry (HcP/MFE3)
# 397        Pham Quoc Dung (HcP/MFE3)
# Name: Change Representative/ Tác giả, Length: 398, dtype: object

# %%
pip install pandas
# Out:
# Looking in indexes: https://anu9rng:****@rb-artifactory.bosch.com/artifactory/api/pypi/python-virtual/simpleNote: you may need to restart the kernel to use updated packages.
#
# ...
#      ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#      ---------------------------------------- 0.1/11.5 MB ? eta -:--:--
#      ---------------------------------------- 0.1/11.5 MB ? eta -:--:--
#      ---------------------------------------- 0.1/11.5 MB ? eta -:--:--
#      ---------------------------------------- 0.1/11.5 MB ? eta -:--:--
#      ---------------------------------------- 0.1/11.5 MB ? eta -:--:--
#       -------------------------------------- 0.2/11.5 MB 655.4 kB/s eta 0:00:18
#       -------------------------------------- 0.2/11.5 MB 655.4 kB/s eta 0:00:18
#       -------------------------------------- 0.2/11.5 MB 655.4 kB/s eta 0:00:18
#       -------------------------------------- 0.2/11.5 MB 655.4 kB/s eta 0:00:18
# ...

# %%
pip install openpyxl
# Out:
# Looking in indexes: https://anu9rng:****@rb-artifactory.bosch.com/artifactory/api/pypi/python-virtual/simpleNote: you may need to restart the kernel to use updated packages.
#
# ...
#      ---------------------------------------- 0.0/251.3 kB ? eta -:--:--
#      ----------------- ---------------------- 112.6/251.3 kB ? eta -:--:--
#      ----------------- ---------------------- 112.6/251.3 kB ? eta -:--:--
#      ----------------- ---------------------- 112.6/251.3 kB ? eta -:--:--
#      ----------------- ---------------------- 112.6/251.3 kB ? eta -:--:--
#      -------------------------------------  245.8/251.3 kB 1.1 MB/s eta 0:00:01
#      ------------------------------------ 251.3/251.3 kB 909.8 kB/s eta 0:00:00
# ...
# WARNING: Skipping C:\Users\RBU1HC\.conda\envs\convert\Lib\site-packages\Bottleneck-1.3.7.dist-info due to invalid metadata entry 'name'
